# %% [markdown]
# # Case When Lab

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lesson, we'll practice working with our case when clause.

# %% [markdown]
# ### Loading our data

# %%
import pandas as pd

df = pd.read_csv('./imdb_top_1000.csv', index_col = 0)
cols = ['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
       'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
       'Star3', 'Star4', 'No_of_Votes', 'Gross']
range(0, df.shape[0])
# Out:
# range(0, 1000)

# %%
df.index = range(0, df.shape[0])

# %%
df[:2]
# Out:
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411

# %%
cols = ['Series_Title', 'Released_Year', 'Runtime', 'Genre',
       'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'No_of_Votes', 'Gross']
selected_df = df[cols]

# %%
selected_df.columns = ['title', 'year', 'runtime', 'genre', 'rating',
       'overview', 'metascore', 'director', 'star', 'votes', 'gross']

# %%
selected_df.to_csv('imdb_selected.csv', index = False)

# %%
df = pd.read_csv('./imdb_selected.csv')

# %%
df[:2]
# Out:
#                       title  year  runtime         genre  rating  \
# 0  The Shawshank Redemption  1994  142 min         Drama     9.3
# 1             The Godfather  1972  175 min  Crime, Drama     9.2
#
#                                             overview  metascore  \
# 0  Two imprisoned men bond over a number of years...       80.0
# 1  An organized crime dynasty's aging patriarch t...      100.0
#
#                director           star    votes        gross
# 0        Frank Darabont    Tim Robbins  2343110   28,341,469
# 1  Francis Ford Coppola  Marlon Brando  1620367  134,966,411

# %%
import sqlite3
conn = sqlite3.connect('./movies.db')
# selected_df.to_sql('movies', conn, index = False, if_exists = 'skip')

# %%
pd.read_sql('SELECT * FROM movies LIMIT 1', conn)
# Out:
#                       title  year  runtime  genre  rating  \
# 0  The Shawshank Redemption  1994  142 min  Drama     9.3
#
#                                             overview  metascore  \
# 0  Two imprisoned men bond over a number of years...       80.0
#
#          director         star    votes       gross
# 0  Frank Darabont  Tim Robbins  2343110  28,341,469

# %%
pd.read_sql('SELECT * FROM movies WHERE gross IS NULL', conn)
# Out:
#                       title  year  runtime                      genre  rating  \
# 0                  Hamilton  2020  160 min  Biography, Drama, History     8.6
# 1           Soorarai Pottru  2020  153 min                      Drama     8.6
# 2                   Seppuku  1962  133 min     Action, Drama, Mystery     8.6
# 3     It's a Wonderful Life  1946  130 min     Drama, Family, Fantasy     8.6
# 4            Hotaru no haka  1988   89 min      Animation, Drama, War     8.5
# ..                      ...   ...      ...                        ...     ...
# 164                  Blowup  1966  111 min   Drama, Mystery, Thriller     7.6
# 165  Breakfast at Tiffany's  1961  115 min     Comedy, Drama, Romance     7.6
# 166                   Giant  1956  201 min             Drama, Western     7.6
# 167                Lifeboat  1944   97 min                 Drama, War     7.6
# 168            The 39 Steps  1935   86 min   Crime, Mystery, Thriller     7.6
#
# ...

# %%
pd.read_csv("s3://jigsaw-labs-student/imdb_movies.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/kx/pltjhhp51mv3hjlcsp0dwlfw0000gn/T/ipykernel_63868/2368004707.py in <module>
# ----> 1 pd.read_csv("s3://jigsaw-labs-student/imdb_movies.csv")
#
# ~/miniconda3/envs/minimal_de/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
